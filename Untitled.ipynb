# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# 读取数据
beta_values = []
gamma_values = []
sentence_acc_3gram_values = []

with open('sina_SMP_3gram_acc_data.txt', 'r') as file:
    for line in file:
        if line.startswith('alpha='):
            parts = line.strip().split(',')
            beta = float(parts[1].split('=')[1])
            gamma = float(parts[2].split('=')[1])
        elif line.startswith('char_acc_3gram='):
            sentence_acc_3gram = float(line.strip().split(',')[1].split('=')[1].strip())
            beta_values.append(beta)
            gamma_values.append(gamma)
            sentence_acc_3gram_values.append(sentence_acc_3gram)

# 绘制热力图
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 为了得到一个平滑的热力图，需要将数据点进行网格化
beta_grid, gamma_grid = np.meshgrid(np.linspace(min(beta_values), max(beta_values), 100),
                                    np.linspace(min(gamma_values), max(gamma_values), 100))
sentence_acc_3gram_grid = griddata((beta_values, gamma_values), sentence_acc_3gram_values, (beta_grid, gamma_grid), method='linear')

# 绘制热力图
surf = ax.plot_trisurf(np.array(beta_values), np.array(gamma_values), np.array(sentence_acc_3gram_values), cmap='viridis', edgecolor='none')

ax.set_xlabel('Beta')
ax.set_ylabel('Gamma')
ax.set_zlabel('Sentence Acc 3-gram')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 29
#      26 # 为了得到一个平滑的热力图，需要将数据点进行网格化
#      27 beta_grid, gamma_grid = np.meshgrid(np.linspace(min(beta_values), max(beta_values), 100),
#      28                                     np.linspace(min(gamma_values), max(gamma_values), 100))
# ---> 29 sentence_acc_3gram_grid = griddata((beta_values, gamma_values), sentence_acc_3gram_values, (beta_grid, gamma_grid), method='linear')
#      31 # 绘制热力图
#      32 surf = ax.plot_trisurf(np.array(beta_values), np.array(gamma_values), np.array(sentence_acc_3gram_values), cmap='viridis', edgecolor='none')
#
# NameError: name 'griddata' is not defined

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# 读取数据
beta_values = []
gamma_values = []
sentence_acc_3gram_values = []

with open('sina_SMP_3gram_acc_data.txt', 'r') as file:
    for line in file:
        if line.startswith('alpha='):
            parts = line.strip().split(',')
            beta = float(parts[1].split('=')[1])
            gamma = float(parts[2].split('=')[1])
        elif line.startswith('char_acc_3gram='):
            sentence_acc_3gram = float(line.strip().split(',')[1].split('=')[1].strip())
            beta_values.append(beta)
            gamma_values.append(gamma)
            sentence_acc_3gram_values.append(sentence_acc_3gram)

# 绘制热力图
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制三角剖分热力图
trisurf = ax.plot_trisurf(beta_values, gamma_values, sentence_acc_3gram_values, cmap='viridis')

ax.set_xlabel('Beta')
ax.set_ylabel('Gamma')
ax.set_zlabel('Sentence Acc 3-gram')

plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# 读取数据
beta_values = []
gamma_values = []
sentence_acc_3gram_values = []

with open('sina_SMP_wenda_3gram_acc_data.txt', 'r') as file:
    for line in file:
        if line.startswith('alpha='):
            parts = line.strip().split(',')
            beta = float(parts[1].split('=')[1])
            gamma = float(parts[2].split('=')[1])
        elif line.startswith('char_acc_3gram='):
            sentence_acc_3gram = float(line.strip().split(',')[1].split('=')[1].strip())
            beta_values.append(beta)
            gamma_values.append(gamma)
            sentence_acc_3gram_values.append(sentence_acc_3gram)

# 绘制热力图
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制三角剖分热力图
trisurf = ax.plot_trisurf(beta_values, gamma_values, sentence_acc_3gram_values, cmap='viridis')

ax.set_xlabel('Beta')
ax.set_ylabel('Gamma')
ax.set_zlabel('Sentence Acc 3-gram')

plt.show()

# %%
# 读取数据
alpha_values = []
sentence_acc_2gram_values = []


with open('sina_SMP_3gram_acc_data.txt', 'r') as file:
    for line in file:
        if line.startswith('alpha='):
            parts = line.strip().split(',')
            alpha = float(parts[0].split('=')[1])
        elif line.startswith('char_acc_2gram='):
            sentence_acc_2gram = float(line.strip().split(',')[1].split('=')[1].strip())
            alpha_values.append(alpha)
            sentence_acc_2gram_values.append(sentence_acc_2gram)

# 绘制图表
plt.plot(alpha_values, sentence_acc_2gram_values, marker='o')
plt.xlabel('Alpha')
plt.ylabel('Sentence Acc 2-gram')
plt.title('Sentence Acc 2-gram vs Alpha')
plt.grid(True)
plt.show()

# %%
# 读取数据
alpha_values = []
sentence_acc_2gram_values = []


with open('sina_SMP_wenda_3gram_acc_data.txt', 'r') as file:
    for line in file:
        if line.startswith('alpha='):
            parts = line.strip().split(',')
            alpha = float(parts[0].split('=')[1])
        elif line.startswith('char_acc_2gram='):
            sentence_acc_2gram = float(line.strip().split(',')[1].split('=')[1].strip())
            alpha_values.append(alpha)
            sentence_acc_2gram_values.append(sentence_acc_2gram)

# 绘制图表
plt.plot(alpha_values, sentence_acc_2gram_values, marker='o')
plt.xlabel('Alpha')
plt.ylabel('Sentence Acc 2-gram')
plt.title('Sentence Acc 2-gram vs Alpha')
plt.grid(True)
plt.show()
